# %%
import numpy as np
import pyerrors as pe

# %%
const_array = np.zeros(100)
obs = pe.Obs([const_array], ['test'])
obs.gamma_method()
print(f"tau_int = {obs.e_tauint['test']}")
# Out:
# tau_int = 0.5
